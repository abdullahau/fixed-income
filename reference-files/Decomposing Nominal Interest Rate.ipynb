# %% [markdown]
# $$(1+\text{Nominal risk-free rate})=(1+\text{Real risk-free rate})\times (1+\text{Expected inflation rate})$$
#
# $$(1+\text{Market-determined interest rate})=(1+\text{Real risk-free rate})\times (1+\text{Inflation premium}) \times (1+\text{Default risk premium}) \times (1+\text{Liquidity premium}) \times (1+\text{Maturity premium})$$

# %% [markdown]
# ![image.png](attachment:image.png)

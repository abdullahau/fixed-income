# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from fredapi import Fred
import yfinance as yf

# %% [markdown]
# ### API Key

# %%
fred = Fred(api_key='71fec7c91ead2ac33f28e21d699f6e6f')

# %% [markdown]
# ### 10-Year U.S. Treasury Yields

# %%
# Market Yield on U.S. Treasury Securities at 10-Year Constant Maturity, Quoted on an Investment Basis (GS10)
gs10 = fred.get_series('GS10')

# %%
plt.figure(dpi=150)
plt.plot(gs10)
plt.ylim(ymin=0, ymax=18)
plt.title('Market Yield on U.S. Treasury Securities at 10-Year Constant Maturity')
plt.xlabel('Year')
plt.ylabel('Daily Average Yield (%)')
# Out:
# Text(0, 0.5, 'Daily Average Yield (%)')

# %% [markdown]
# ### S&P 500

# %%
sp500 = yf.Ticker('^GSPC')
hist = sp500.history(period='10y', interval='1d')

plt.figure(dpi=120)
plt.plot(hist['Close'])
plt.title('S&P 500 Closing Price')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
# Out:
# Text(0, 0.5, 'Closing Price (USD)')

# %% [markdown]
# ### CBOE Volatility Index: VIX

# %%
vix = fred.get_series('VIXCLS')

# %%
plt.figure(dpi=120)
plt.plot(vix)
plt.title('CBOE Volatility Index: VIX')
plt.xlabel('Year')
plt.ylabel('30-day expected volatility of the S&P500 index')
# Out:
# Text(0, 0.5, '30-day expected volatility of the S&P500 index')

# %% [markdown]
# ### Global price of WTI & Brent Crude

# %%
wti = fred.get_series('POILWTIUSDM')
brent = fred.get_series('POILBREUSDM')

# %%
plt.figure(dpi=120)
plt.plot(wti)
plt.title('Global price of WTI Crude')
plt.xlabel('Year')
plt.ylabel('U.S. Dollars per Barrel')
# Out:
# Text(0, 0.5, 'U.S. Dollars per Barrel')

# %%
plt.figure(dpi=120)
plt.plot(brent)
plt.title('Global price of Brent Crude')
plt.xlabel('Year')
plt.ylabel('U.S. Dollars per Barrel')
# Out:
# Text(0, 0.5, 'U.S. Dollars per Barrel')

# %% [markdown]
# ### Option Screener

# %%
import pandas as pd

appl = yf.Ticker('AAPL')

chain = appl.option_chain('2024-12-20')
pd.DataFrame(chain.calls).to_csv('call_option_chain.csv')
pd.DataFrame(chain.puts).to_csv('puts_option_chain.csv')
